# %%
import requests
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart

# Weather API configuration
api_key = "d84557d1c627bc0ee888aa6e0f565043"
city_name = input("enter city name")  # Replace with the desired city name
weather_api_url = f"http://api.openweathermap.org/data/2.5/weather?q={city_name}&appid={api_key}"

# Email configuration
sender_email = "rimi.n.k.123@gmail.com"
receiver_email = "ariyan.bhakat@gmail.com"
smtp_server = "smtp.gmail.com"
smtp_port = 587
smtp_username = "rimi.n.k.123@gmail.com"
smtp_password = "lzqz tyas cawd xxfw"

# Fetch live weather data
response = requests.get(weather_api_url)
weather_data = response.json()

# Extract relevant weather information
temperature = weather_data["main"]["temp"]
humidity = weather_data["main"]["humidity"]
description = weather_data["weather"][0]["description"]

# Create the email content
subject = f"Weather Update for {city_name}"
temp=temperature-273
body = f"Temperature: {temp}°C\nHumidity: {humidity}%\nConditions: {description}"

msg = MIMEMultipart()
msg["From"] = sender_email
msg["To"] = receiver_email
msg["Subject"] = subject
msg.attach(MIMEText(body, "plain"))

# Establish an SMTP connection and send the email
try:
    server = smtplib.SMTP(smtp_server, smtp_port)
    server.starttls()
    server.login(smtp_username, smtp_password)
    server.sendmail(sender_email, receiver_email, msg.as_string())
    print("Weather update email sent successfully")
except Exception as e:
    print(f"Error: {str(e)}")
finally:
    server.quit()
# Out:
# enter city nameKolkata
# Weather update email sent successfully

# %%
import pandas as pd
import time

# Function to calculate the dam gate opening percentage based on temperature and humidity readings
def calculate_opening_percentage(temperature, humidity):
    
    opening_percentage = (temperature - 20) + (humidity - 50) / 2
    opening_percentage = max(0, min(100, opening_percentage))
    
    return opening_percentage

def control_dam_gate(opening_percentage):
    print(f"Opening the dam gate to {opening_percentage}%")

csv_file_path = 'weather_data_kolkata_2015_2020.csv'

try:
    df = pd.read_csv(csv_file_path)

    for index, row in df.iterrows():
        temperature = row['TEMPERATURE']
        humidity = row['HUMIDITY']
        
        # Calculate the dam gate opening percentage
        opening_percentage = calculate_opening_percentage(temperature, humidity)
        
        # Control the dam gate based on the opening percentage
        control_dam_gate(opening_percentage)
        
        
    print("Finished controlling the dam gate.")

except FileNotFoundError:
    print(f"CSV file not found at {csv_file_path}")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Opening the dam gate to 11.5%
# Opening the dam gate to 12.5%
# Opening the dam gate to 13.0%
# Opening the dam gate to 14.0%
# Opening the dam gate to 14.5%
# Opening the dam gate to 16.5%
# Opening the dam gate to 17.0%
# Opening the dam gate to 16.0%
# Opening the dam gate to 16.0%
# Opening the dam gate to 16.0%
# Opening the dam gate to 15.5%
# Opening the dam gate to 15.0%
# Opening the dam gate to 15.0%
# Opening the dam gate to 16.0%
# Opening the dam gate to 17.5%
# Opening the dam gate to 18.5%
# Opening the dam gate to 19.0%
# Opening the dam gate to 20.0%
# Opening the dam gate to 20.5%
# Opening the dam gate to 20.5%
# Opening the dam gate to 20.5%
# Opening the dam gate to 20.5%
# Opening the dam gate to 20.5%
# Opening the dam gate to 20.5%
# Opening the dam gate to 20.5%
# Opening the dam gate to 19.5%
# Opening the dam gate to 19.5%
# Opening the dam gate to 20.0%
# Opening the dam gate to 18.0%
# Opening the dam gate to 17.0%
# Opening the dam gate to 16.5%
# ...

# %%
# Function to calculate dam gate opening percentage
def calculate_gate_opening(barometer_reading, soil_moisture, weather_condition, temperature):
    
    # Example formula (this is just a placeholder, not based on actual engineering data)
    gate_opening_percentage = (barometer_reading * 0.2 + soil_moisture * 0.3 - weather_condition * 0.1 + temperature * 0.4) / 10
    
    # Ensure the gate opening percentage is within a valid range (0 to 100)
    gate_opening_percentage = max(0, min(100, gate_opening_percentage))
    
    return gate_opening_percentage

# Example data inputs (replace with actual data)
barometer_reading = 1015.2
soil_moisture = 0.6
weather_condition = 0.2
temperature = 25.5

# Calculate the dam gate opening percentage
gate_opening_percentage = calculate_gate_opening(barometer_reading, soil_moisture, weather_condition, temperature)

# Print the result
print(f"Dam gate opening percentage: {gate_opening_percentage:.2f}%")
# Out:
# Dam gate opening percentage: 21.34%
